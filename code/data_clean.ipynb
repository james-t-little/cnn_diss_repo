# %%
import pandas as pd
import numpy as np
import os
import random
import matplotlib.image as mpimg
from  matplotlib import pyplot as plt
import matplotlib.image as mpimg
import PIL

# %%
input_directory = r'C:\Users\james\Documents\dissertation_seg_data\input'

output_directory = r'C:\Users\james\Documents\dissertation_seg_data\segmented_output'

plt.figure(figsize=(20,20))

def show_data(directory):
    plt.figure(figsize=(20,20))
    for i in range(5):
        file = random.choice(os.listdir(directory))
        image_path= os.path.join(directory, file)
        img=mpimg.imread(image_path)
        ax=plt.subplot(1,5,i+1)
        ax.title.set_text(file)
        plt.imshow(img)

show_data(input_directory)

show_data(output_directory)
# Out:
# C:\Users\james\Documents\dissertation_seg_data\input\paris236_image.png
# C:\Users\james\Documents\dissertation_seg_data\input\berlin6_image.png
# C:\Users\james\Documents\dissertation_seg_data\input\paris90_image.png
# C:\Users\james\Documents\dissertation_seg_data\input\chicago467_image.png
# C:\Users\james\Documents\dissertation_seg_data\input\chicago470_image.png
# C:\Users\james\Documents\dissertation_seg_data\segmented_output\paris229_labels.png
# C:\Users\james\Documents\dissertation_seg_data\segmented_output\chicago12_labels.png
# C:\Users\james\Documents\dissertation_seg_data\segmented_output\chicago234_labels.png
# C:\Users\james\Documents\dissertation_seg_data\segmented_output\paris312_labels.png
# C:\Users\james\Documents\dissertation_seg_data\segmented_output\berlin118_labels.png

# %%
input_images =
# Out:
# ['berlin', 'chicago', 'paris', 'potsdam', 'tokyo']
# ['berlin', 'chicago', 'paris', 'potsdam', 'tokyo']
# []
# []
# ...

# %%
def show_data():
    return 

def create_dataset():
    return

def merge_dataset():
    return
